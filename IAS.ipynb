# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("/content/IAS.csv")

# %%
df
# Out:
#        RowID      State_Name  District_Name  Crop_Year       Season  \
# 0          0           Bihar        NALANDA       2005  Rabi
# 1          1           Assam  KARBI ANGLONG       2019  Whole Year
# 2          2         Gujarat          ANAND       2020  Summer
# 3          3       Karnataka   UTTAR KANNAD       2013  Rabi
# 4          4   Uttar Pradesh        JAUNPUR       2016  Rabi
# ...      ...             ...            ...        ...          ...
# 73822  73822           Bihar          BUXAR       2012  Whole Year
# 73823  73823  Madhya Pradesh        RAJGARH       2021  Kharif
# 73824  73824  Madhya Pradesh        RAJGARH       2006  Kharif
# 73825  73825       Rajasthan           TONK       2008  Kharif
# 73826  73826       Jharkhand        KODERMA       2010  Winter
#
#             Crop      Area  Production
# 0          Wheat  81934.00   160425.00
# 1          Onion    257.00      514.00
# 2          Maize    100.00      100.00
# ...

# %%
df.head()
# Out:
#    RowID     State_Name  District_Name  Crop_Year       Season       Crop  \
# 0      0          Bihar        NALANDA       2005  Rabi             Wheat
# 1      1          Assam  KARBI ANGLONG       2019  Whole Year       Onion
# 2      2        Gujarat          ANAND       2020  Summer           Maize
# 3      3      Karnataka   UTTAR KANNAD       2013  Rabi         Groundnut
# 4      4  Uttar Pradesh        JAUNPUR       2016  Rabi             Onion
#
#       Area  Production
# 0  81934.0    160425.0
# 1    257.0       514.0
# 2    100.0       100.0
# 3   2872.0      4572.0
# 4    110.0      1290.0

# %%
df.tail()
# Out:
#        RowID      State_Name District_Name  Crop_Year       Season       Crop  \
# 73822  73822           Bihar         BUXAR       2012  Whole Year       Onion
# 73823  73823  Madhya Pradesh       RAJGARH       2021  Kharif           Bajra
# 73824  73824  Madhya Pradesh       RAJGARH       2006  Kharif       Groundnut
# 73825  73825       Rajasthan          TONK       2008  Kharif           Bajra
# 73826  73826       Jharkhand       KODERMA       2010  Winter            Rice
#
#            Area  Production
# 73822    203.00     1918.00
# 73823     12.00       11.00
# 73824   8700.00     9100.00
# 73825  34477.00    20137.00
# 73826  14685.71    18552.95

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 73827 entries, 0 to 73826
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   RowID          73827 non-null  int64
#  1   State_Name     73827 non-null  object
#  2   District_Name  73827 non-null  object
#  3   Crop_Year      73827 non-null  int64
#  4   Season         73827 non-null  object
#  5   Crop           73827 non-null  object
#  6   Area           73827 non-null  float64
#  7   Production     72731 non-null  float64
# dtypes: float64(2), int64(2), object(4)
# memory usage: 4.5+ MB

# %%
df.describe()
# Out:
#               RowID     Crop_Year          Area    Production
# count  73827.000000  73827.000000  7.382700e+04  7.273100e+04
# mean   36913.000000   2013.657551  1.218297e+04  6.210320e+05
# std    21312.163499      4.954910  5.348285e+04  1.749756e+07
# min        0.000000   2005.000000  4.000000e-02  0.000000e+00
# 25%    18456.500000   2010.000000  8.100000e+01  8.900000e+01
# 50%    36913.000000   2014.000000  5.900000e+02  7.290000e+02
# 75%    55369.500000   2018.000000  4.500000e+03  7.200000e+03
# max    73826.000000   2023.000000  8.580100e+06  1.125000e+09

# %%
df.isnull()
# Out:
#        RowID  State_Name  District_Name  Crop_Year  Season   Crop   Area  \
# 0      False       False          False      False   False  False  False
# 1      False       False          False      False   False  False  False
# 2      False       False          False      False   False  False  False
# 3      False       False          False      False   False  False  False
# 4      False       False          False      False   False  False  False
# ...      ...         ...            ...        ...     ...    ...    ...
# 73822  False       False          False      False   False  False  False
# 73823  False       False          False      False   False  False  False
# 73824  False       False          False      False   False  False  False
# 73825  False       False          False      False   False  False  False
# 73826  False       False          False      False   False  False  False
#
#        Production
# 0           False
# 1           False
# 2           False
# ...

# %%
df.isnull().sum()
# Out:
# RowID               0
# State_Name          0
# District_Name       0
# Crop_Year           0
# Season              0
# Crop                0
# Area                0
# Production       1096
# dtype: int64

# %%
df['Production'] = df['Production'].fillna(df['Production'].mean())

# %%
df.isnull().sum()
# Out:
# RowID            0
# State_Name       0
# District_Name    0
# Crop_Year        0
# Season           0
# Crop             0
# Area             0
# Production       0
# dtype: int64

# %%
df.columns
# Out:
# Index(['RowID', 'State_Name', 'District_Name', 'Crop_Year', 'Season', 'Crop',
#        'Area', 'Production'],
#       dtype='object')

# %%
df.shape
# Out:
# (73827, 8)

# %%
df.groupby('Crop_Year')['Production'].max()
# Out:
# Crop_Year
# 2005    2.832200e+07
# 2006    2.880000e+08
# 2007    6.080000e+08
# 2008    6.350000e+08
# 2009    6.270000e+08
# 2010    8.880000e+08
# 2011    4.190000e+08
# 2012    9.000000e+08
# 2013    8.450000e+08
# 2014    8.240000e+08
# 2015    8.510000e+08
# 2016    4.929366e+08
# 2017    8.680000e+08
# 2018    5.287900e+08
# 2019    8.238000e+08
# 2020    1.125000e+09
# 2021    9.350000e+08
# 2022    4.850000e+08
# 2023    6.210320e+05
# Name: Production, dtype: float64

# %%
x =df['Crop_Year']
y=df['Production']
plt.scatter(x,y)
plt.show()

# %%
#state wise analysis of crop production and year

# Group data by state and crop year, then calculate the sum of production for each group
state_wise_production = df.groupby(['State_Name', 'Crop_Year'])['Production'].sum().reset_index()

# Display the result
print(state_wise_production)

# Example: Plot production trend for a specific state
state_name = 'Uttar Pradesh'  # Replace with the desired state
state_data = state_wise_production[state_wise_production['State_Name'] == state_name]
plt.figure(figsize=(10, 6))
plt.plot(state_data['Crop_Year'], state_data['Production'], marker='o')
plt.xlabel('Crop Year')
plt.ylabel('Total Production')
plt.title(f'Crop Production Trend in {state_name}')
plt.grid(True)
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.show()


#Further analysis can be done with other states or aggregate data
# Out:
#                       State_Name  Crop_Year   Production
# 0    Andaman and Nicobar Islands       2008  89011085.00
# 1    Andaman and Nicobar Islands       2009      2616.00
# 2    Andaman and Nicobar Islands       2010      2565.81
# 3    Andaman and Nicobar Islands       2011      9106.38
# 4    Andaman and Nicobar Islands       2012  34786177.19
# ..                           ...        ...          ...
# 510                  West Bengal       2018  12338035.00
# 511                  West Bengal       2019  10949803.00
# 512                  West Bengal       2020  13498244.00
# 513                  West Bengal       2021  13494606.00
# 514                  West Bengal       2022  18302156.00
#
# [515 rows x 3 columns]

# %%
#State wise analysis of crop type, production

# Group data by state and crop type, then calculate the sum of production for each group
state_crop_production = df.groupby(['State_Name', 'Crop'])['Production'].sum().reset_index()

# Display the result
print(state_crop_production)

# Example: Plot production of different crops for a specific state
state_name = 'Karnataka'  # Replace with the desired state
state_crop_data = state_crop_production[state_crop_production['State_Name'] == state_name]

plt.figure(figsize=(12, 6))
sns.barplot(x='Crop', y='Production', data=state_crop_data)
plt.xlabel('Crop Type')
plt.ylabel('Total Production')
plt.title(f'Crop Production in {state_name}')
plt.xticks(rotation=90)  # Rotate x-axis labels for better readability
plt.show()
# Out:
#                        State_Name          Crop    Production
# 0     Andaman and Nicobar Islands      Arecanut  2.360566e+04
# 1     Andaman and Nicobar Islands        Banana  3.682000e+03
# 2     Andaman and Nicobar Islands  Black pepper  5.856800e+02
# 3     Andaman and Nicobar Islands     Cashewnut  5.692600e+02
# 4     Andaman and Nicobar Islands      Coconut   2.935500e+08
# ...                           ...           ...           ...
# 1212                  West Bengal     Sunflower  2.801800e+04
# 1213                  West Bengal       Tobacco  1.498330e+05
# 1214                  West Bengal      Turmeric  8.862400e+04
# 1215                  West Bengal          Urad  8.371930e+05
# 1216                  West Bengal         Wheat  5.328014e+06
#
# [1217 rows x 3 columns]

# %%
# state with most and least production

# Find the state with the maximum and minimum total production
total_production_by_state = df.groupby('State_Name')['Production'].sum()
state_with_max_production = total_production_by_state.idxmax()
state_with_min_production = total_production_by_state.idxmin()

print(f"State with maximum total production: {state_with_max_production}")
print(f"State with minimum total production: {state_with_min_production}")
# Out:
# State with maximum total production: Kerala
# State with minimum total production: Chandigarh

# %%
# Example: Plot production of different crops for a specific state
state_name = 'Chandigarh'  # Replace with the desired state
state_crop_data = state_crop_production[state_crop_production['State_Name'] == state_name]

plt.figure(figsize=(12, 6))
sns.barplot(x='Crop', y='Production', data=state_crop_data)
plt.xlabel('Crop Type')
plt.ylabel('Total Production')
plt.title(f'Crop Production in {state_name}')
plt.xticks(rotation=90)  # Rotate x-axis labels for better readability
plt.show()

# %%
# prompt: State wise analysis of crop type, production, season, year no need to plot graph

# Group data by state, crop, season, and year, then calculate the sum of production
state_crop_season_year_production = df.groupby(['State_Name', 'Crop', 'Season', 'Crop_Year'])['Production'].sum().reset_index()

# Display the result
state_crop_season_year_production
# Out:
#                         State_Name      Crop       Season  Crop_Year  \
# 0      Andaman and Nicobar Islands  Arecanut  Kharif            2008
# 1      Andaman and Nicobar Islands  Arecanut  Rabi              2018
# 2      Andaman and Nicobar Islands  Arecanut  Whole Year        2011
# 3      Andaman and Nicobar Islands  Arecanut  Whole Year        2012
# 4      Andaman and Nicobar Islands  Arecanut  Whole Year        2013
# ...                            ...       ...          ...        ...
# 13744                  West Bengal     Wheat  Rabi              2018
# 13745                  West Bengal     Wheat  Rabi              2019
# 13746                  West Bengal     Wheat  Rabi              2020
# 13747                  West Bengal     Wheat  Rabi              2021
# 13748                  West Bengal     Wheat  Rabi              2022
#
#        Production
# 0         7200.00
# 1         4190.00
# 2         5182.00
# 3         3975.20
# 4         3058.46
# ...           ...
# ...

# %%
# Group data by state, crop, season, and year, then calculate the sum of production
state_crop_season_year_production1= df.groupby(['State_Name', 'Crop', 'Season', 'Crop_Year'])['Production'].max()
state_crop_season_year_production1
# Out:
# State_Name                   Crop      Season       Crop_Year
# Andaman and Nicobar Islands  Arecanut  Kharif       2008           5200.00
#                                        Rabi         2018           2290.00
#                                        Whole Year   2011           5182.00
#                                                     2012           3975.20
#                                                     2013           3058.46
#                                                                    ...
# West Bengal                  Wheat     Rabi         2018         143989.00
#                                                     2019         131848.00
#                                                     2020         285342.00
#                                                     2021         131682.00
#                                                     2022         300497.00
# Name: Production, Length: 13749, dtype: float64

# %%
#suggest the crop to be produced in specific state according to the season

state_crop_season_year_production_2= df.groupby(['State_Name', 'Crop', 'Season'])['Production'].sum()

state_crop_season_year_production_2
# Out:
# State_Name                   Crop          Season
# Andaman and Nicobar Islands  Arecanut      Kharif         7.200000e+03
#                                            Rabi           4.190000e+03
#                                            Whole Year     1.221566e+04
#                              Banana        Whole Year     3.682000e+03
#                              Black pepper  Rabi           1.200000e+02
#                                                               ...
# West Bengal                  Tobacco       Whole Year     1.498330e+05
#                              Turmeric      Whole Year     8.862400e+04
#                              Urad          Kharif         7.908990e+05
#                                            Rabi           4.629400e+04
#                              Wheat         Rabi           5.328014e+06
# Name: Production, Length: 1844, dtype: float64

# %%
# prompt: #suggest the crop to be produced in specific state according to the season  call the function

def suggest_crop(state, season):
  """
  Suggests a crop to be produced in a specific state according to the season.

  Args:
    state: The name of the state.
    season: The season.

  Returns:
    The name of the suggested crop, or None if no suggestion can be made.
  """
  try:
    # Filter data for the given state and season
    state_season_data = state_crop_season_year_production_2.loc[state, :].loc[:, season]

    # Find the crop with the maximum production for the given state and season
    suggested_crop = state_season_data.idxmax()

    return suggested_crop
  except KeyError:
    return None

# %%
# Example usage
state = 'Bihar'  # Replace with the desired state
season = 'Rabi'  # Replace with the desired season
suggested_crop = suggest_crop(state, season)

if suggested_crop:
    print(f"Suggested crop for {state} in {season} season: {suggested_crop}")
else:
    print(f"No suggestion available for {state} in {season} season.")
# Out:
# No suggestion available for Bihar in Rabi season.

# %%
# prompt: suggest crop season wise for each state

def suggest_crop(state, season):
  """
  Suggests a crop to be produced in a specific state according to the season.

  Args:
    state: The name of the state.
    season: The season.

  Returns:
    The name of the suggested crop, or None if no suggestion can be made.
  """
  try:
    # Filter data for the given state and season
    state_season_data = state_crop_season_year_production_2.loc[state, :].loc[:, season]

    # Find the crop with the maximum production for the given state and season
    suggested_crop = state_season_data.idxmax()

    return suggested_crop
  except KeyError:
    return None

# Example usage (you can modify these)
state = 'Punjab'  # Replace with desired state
season = 'Kharif'  # Replace with desired season
suggested_crop = suggest_crop(state, season)

if suggested_crop:
    print(f"Suggested crop for {state} in {season} season: {suggested_crop}")
else:
    print(f"No suggestion available for {state} in {season} season.")


#Iterate through states and seasons to get suggestions for all combinations

#Get unique states and seasons
states = df['State_Name'].unique()
seasons = df['Season'].unique()

for state in states:
    for season in seasons:
        suggested_crop = suggest_crop(state, season)
        if suggested_crop:
            print(f"Suggested crop for {state} in {season} season: {suggested_crop}")
        else:
            print(f"No suggestion available for {state} in {season} season.")
# Out:
# No suggestion available for Punjab in Kharif season.
# Suggested crop for Bihar in Rabi        season: Wheat
# Suggested crop for Bihar in Whole Year  season: Sugarcane
# Suggested crop for Bihar in Summer      season: Maize
# Suggested crop for Bihar in Winter      season: Rice
# Suggested crop for Bihar in Kharif      season: Jute
# Suggested crop for Bihar in Autumn      season: Rice
# Suggested crop for Assam in Rabi        season: Rapeseed &Mustard
# Suggested crop for Assam in Whole Year  season: Coconut
# Suggested crop for Assam in Summer      season: Rice
# Suggested crop for Assam in Winter      season: Rice
# Suggested crop for Assam in Kharif      season: Jute
# Suggested crop for Assam in Autumn      season: Rice
# Suggested crop for Gujarat in Rabi        season: Wheat
# Suggested crop for Gujarat in Whole Year  season: Sugarcane
# Suggested crop for Gujarat in Summer      season: Bajra
# No suggestion available for Gujarat in Winter      season.
# ...

# %%
df.groupby('Area')['Production'].sum()
# Out:
# Area
# 0.04          6.210320e+05
# 0.05          6.210320e+05
# 0.07          6.210320e+05
# 0.11          6.210320e+05
# 0.28          2.000000e-02
#                   ...
# 1250800.00    5.614000e+05
# 1403200.00    6.148000e+05
# 3179900.00    2.118200e+06
# 3304700.00    2.712500e+06
# 8580100.00    7.556300e+06
# Name: Production, Length: 17798, dtype: float64

# %% [markdown]
# use heatmap to find season and suggested crop

# %%
# prompt: use heatmap to find season and suggested crop


# Assuming 'state_crop_season_year_production_2' is already defined as in your previous code

# Pivot the data for the heatmap
heatmap_data = state_crop_season_year_production_2.unstack()

# Plotting the heatmap
plt.figure(figsize=(25, 65))
sns.heatmap(heatmap_data, annot=False, cmap='viridis', fmt=".0f")
plt.title("Crop Production by State and Season")
plt.xlabel("Season")
plt.ylabel("State")
plt.show()

# %%
# Pivot the data for the heatmap
heatmap_data1 = state_crop_season_year_production1.unstack()

# Plotting the heatmap
plt.figure(figsize=(25, 45))
sns.heatmap(heatmap_data1, annot=False, cmap='viridis', fmt=".0f")
plt.title("Crop Production by State and Season")
plt.xlabel("Season")
plt.ylabel("State")
plt.show()
